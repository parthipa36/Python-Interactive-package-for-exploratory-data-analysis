# %% [markdown]
# # Python - Saving Graphs as image files

# %% [markdown]
# #### Note: Please kindly save the local package named "GraphsToImages.py" in the current working directory of this notebook.

# %%
# Exporting the local package GraphsToImages
from GraphsToImages import Graphs_univariate #For only univariate graphs
from GraphsToImages import Graphs #For both univariate and bivariate Graphs

# %%
import pandas as pd

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %% [markdown]
# #### Below one will generate images of univariate graphs of the data frame cars and save it to the same current working directory

# %%
Graphs(cars)

# %% [markdown]
# #### Below one will generate images of univariate graphs of the data frame cars for only the attributes of passed indexes var (3,4,5) and save it to the mentioned directory with the additional characteristics such as figure size, color of the bars and edge colors also.

# %%
Graphs(cars, var=[3,4,5], direc=r"C:\Users\PARTHI vs BHARATHI\PY_END_JUL18_Parthipan_Gontla Praveen\Graphs_univariate", figsize=(18,12), color='blue', edgecolor='black')

# %% [markdown]
# #### Below one will generate images of bivariate graphs of the data frame cars with the target variable y given as "MPG" and store it in the given directory

# %%
Graphs(cars,target_y='MPG',direc=r"C:\Users\PARTHI vs BHARATHI\PY_END_JUL18_Parthipan_Gontla Praveen\Graphs_bivariate") #Plese ensure that you have created this folder in your machine.
